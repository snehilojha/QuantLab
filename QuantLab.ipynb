# %%
import yfinance as yf
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows', None)

# %%
ticker = ['^NSEI','ZENTEC.NS','RELIANCE.NS','TCS.NS','INFY.NS','SBIN.NS','TATAMOTORS.NS','INDIGO.NS','TATAPOWER.NS','KPITTECH.NS','ANANTRAJ.NS','ANANDRATHI.NS','PRUDENT.NS','SHILCTECH.BO','WAAREERTL.BO']

# %%
stocks = yf.download(ticker, start = "2010-01-01", end = "2025-08-01")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6440\3909581967.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   stocks = yf.download(ticker, start = "2010-01-01", end = "2025-08-01")
# [*********************100%***********************]  15 of 15 completed

# %%
stocks
# Out:
# Price              Close                                                  \
# Ticker     ANANDRATHI.NS ANANTRAJ.NS INDIGO.NS      INFY.NS  KPITTECH.NS
# Date
# 2010-01-04           NaN   49.145935       NaN   233.268631          NaN
# 2010-01-05           NaN   48.525452       NaN   234.049896          NaN
# 2010-01-06           NaN   52.248360       NaN   230.634644          NaN
# 2010-01-07           NaN   51.080395       NaN   225.451630          NaN
# 2010-01-08           NaN   52.522091       NaN   220.018616          NaN
# ...                  ...         ...       ...          ...          ...
# 2025-07-25   2596.199951  573.450012    5803.0  1515.699951  1221.199951
# 2025-07-28   2643.600098  563.099976    5762.0  1516.000000  1192.800049
# 2025-07-29   2688.300049  578.400024    5756.0  1513.699951  1218.400024
# 2025-07-30   2671.399902  579.799988    5740.0  1519.000000  1268.500000
# 2025-07-31   2645.600098  564.599976    5910.5  1509.000000  1226.400024
#
# ...

# %%
stocks.head()
# Out:
# Price              Close                                                \
# Ticker     ANANDRATHI.NS ANANTRAJ.NS INDIGO.NS     INFY.NS KPITTECH.NS
# Date
# 2010-01-04           NaN   49.145935       NaN  233.268631         NaN
# 2010-01-05           NaN   48.525452       NaN  234.049896         NaN
# 2010-01-06           NaN   52.248360       NaN  230.634644         NaN
# 2010-01-07           NaN   51.080395       NaN  225.451630         NaN
# 2010-01-08           NaN   52.522091       NaN  220.018616         NaN
#
# Price                                                                     ...  \
# Ticker     PRUDENT.NS RELIANCE.NS     SBIN.NS SHILCTECH.BO TATAMOTORS.NS  ...
# Date                                                                      ...
# 2010-01-04        NaN  219.466110  188.699768    28.150000    151.363586  ...
# 2010-01-05        NaN  218.486618  188.769775    28.116667    148.726227  ...
# ...

# %%
stocks.tail()
# Out:
# Price              Close                                                  \
# Ticker     ANANDRATHI.NS ANANTRAJ.NS INDIGO.NS      INFY.NS  KPITTECH.NS
# Date
# 2025-07-25   2596.199951  573.450012    5803.0  1515.699951  1221.199951
# 2025-07-28   2643.600098  563.099976    5762.0  1516.000000  1192.800049
# 2025-07-29   2688.300049  578.400024    5756.0  1513.699951  1218.400024
# 2025-07-30   2671.399902  579.799988    5740.0  1519.000000  1268.500000
# 2025-07-31   2645.600098  564.599976    5910.5  1509.000000  1226.400024
#
# Price                                                                        \
# Ticker       PRUDENT.NS  RELIANCE.NS     SBIN.NS SHILCTECH.BO TATAMOTORS.NS
# Date
# 2025-07-25  2896.199951  1391.699951  806.549988  4898.450195    687.400024
# 2025-07-28  2920.800049  1387.599976  797.150024  4801.000000    682.900024
# 2025-07-29  3004.000000  1417.099976  799.200012  5260.500000    692.349976
# ...

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3848 entries, 2010-01-04 to 2025-07-31
# Data columns (total 75 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   (Close, ANANDRATHI.NS)   899 non-null    float64
#  1   (Close, ANANTRAJ.NS)     3846 non-null   float64
#  2   (Close, INDIGO.NS)       2401 non-null   float64
#  3   (Close, INFY.NS)         3846 non-null   float64
#  4   (Close, KPITTECH.NS)     1554 non-null   float64
#  5   (Close, PRUDENT.NS)      792 non-null    float64
#  6   (Close, RELIANCE.NS)     3846 non-null   float64
#  7   (Close, SBIN.NS)         3846 non-null   float64
#  8   (Close, SHILCTECH.BO)    3116 non-null   float64
#  9   (Close, TATAMOTORS.NS)   3846 non-null   float64
#  10  (Close, TATAPOWER.NS)    3846 non-null   float64
#  11  (Close, TCS.NS)          3846 non-null   float64
#  12  (Close, WAAREERTL.BO)    2288 non-null   float64
# ...

# %%
stocks.to_csv("algostocks.csv")

# %%
stocks = pd.read_csv("algostocks.csv")

# %%
stocks
# Out:
#            Price              Close            Close.1    Close.2  \
# 0         Ticker      ANANDRATHI.NS        ANANTRAJ.NS  INDIGO.NS
# 1           Date                NaN                NaN        NaN
# 2     2010-01-04                NaN  49.14593505859375        NaN
# 3     2010-01-05                NaN  48.52545166015625        NaN
# 4     2010-01-06                NaN  52.24835968017578        NaN
# ...          ...                ...                ...        ...
# 3845  2025-07-25  2596.199951171875  573.4500122070312     5803.0
# 3846  2025-07-28   2643.60009765625  563.0999755859375     5762.0
# 3847  2025-07-29  2688.300048828125  578.4000244140625     5756.0
# 3848  2025-07-30   2671.39990234375  579.7999877929688     5740.0
# 3849  2025-07-31   2645.60009765625  564.5999755859375     5910.5
#
#                  Close.3             Close.4            Close.5  \
# 0                INFY.NS         KPITTECH.NS         PRUDENT.NS
# ...

# %%
stocks = pd.read_csv("algostocks.csv",header = [0,1])
stocks
# Out:
#            Price         Close                                     \
#           Ticker ANANDRATHI.NS ANANTRAJ.NS INDIGO.NS      INFY.NS
# 0           Date           NaN         NaN       NaN          NaN
# 1     2010-01-04           NaN   49.145935       NaN   233.268631
# 2     2010-01-05           NaN   48.525452       NaN   234.049896
# 3     2010-01-06           NaN   52.248360       NaN   230.634644
# 4     2010-01-07           NaN   51.080395       NaN   225.451630
# ...          ...           ...         ...       ...          ...
# 3844  2025-07-25   2596.199951  573.450012    5803.0  1515.699951
# 3845  2025-07-28   2643.600098  563.099976    5762.0  1516.000000
# 3846  2025-07-29   2688.300049  578.400024    5756.0  1513.699951
# 3847  2025-07-30   2671.399902  579.799988    5740.0  1519.000000
# 3848  2025-07-31   2645.600098  564.599976    5910.5  1509.000000
#
#                                                                       ...  \
# ...

# %%
stocks = pd.read_csv("algostocks.csv",header = [0,1], index_col= [0])
stocks
# Out:
# Price              Close                                                  \
# Ticker     ANANDRATHI.NS ANANTRAJ.NS INDIGO.NS      INFY.NS  KPITTECH.NS
# Date
# 2010-01-04           NaN   49.145935       NaN   233.268631          NaN
# 2010-01-05           NaN   48.525452       NaN   234.049896          NaN
# 2010-01-06           NaN   52.248360       NaN   230.634644          NaN
# 2010-01-07           NaN   51.080395       NaN   225.451630          NaN
# 2010-01-08           NaN   52.522091       NaN   220.018616          NaN
# ...                  ...         ...       ...          ...          ...
# 2025-07-25   2596.199951  573.450012    5803.0  1515.699951  1221.199951
# 2025-07-28   2643.600098  563.099976    5762.0  1516.000000  1192.800049
# 2025-07-29   2688.300049  578.400024    5756.0  1513.699951  1218.400024
# 2025-07-30   2671.399902  579.799988    5740.0  1519.000000  1268.500000
# 2025-07-31   2645.600098  564.599976    5910.5  1509.000000  1226.400024
#
# ...

# %%
stocks = pd.read_csv("algostocks.csv",header = [0,1], index_col= [0], parse_dates=[0])
stocks
# Out:
# Price              Close                                                  \
# Ticker     ANANDRATHI.NS ANANTRAJ.NS INDIGO.NS      INFY.NS  KPITTECH.NS
# Date
# 2010-01-04           NaN   49.145935       NaN   233.268631          NaN
# 2010-01-05           NaN   48.525452       NaN   234.049896          NaN
# 2010-01-06           NaN   52.248360       NaN   230.634644          NaN
# 2010-01-07           NaN   51.080395       NaN   225.451630          NaN
# 2010-01-08           NaN   52.522091       NaN   220.018616          NaN
# ...                  ...         ...       ...          ...          ...
# 2025-07-25   2596.199951  573.450012    5803.0  1515.699951  1221.199951
# 2025-07-28   2643.600098  563.099976    5762.0  1516.000000  1192.800049
# 2025-07-29   2688.300049  578.400024    5756.0  1513.699951  1218.400024
# 2025-07-30   2671.399902  579.799988    5740.0  1519.000000  1268.500000
# 2025-07-31   2645.600098  564.599976    5910.5  1509.000000  1226.400024
#
# ...

# %%
stocks= stocks.rename(columns={'ZENTEC.NS':'ZENTEC','WAAREERTL.BO':'WAAREERTL','SHILCTECH.BO':'SHILCTECH','INFY.NS':'INFY', 'TCS.NS':'TCS','RELIANCE.NS':'RELIANCE','^NSEI':'NSEI','TATAMOTORS.NS':'TATAMOTORS','TATAPOWER.NS':'TATAPOWER','INDIGO.NS':'INDIGO','SBIN.NS':'SBIN','KPITTECH.NS':'KPITTECH','ANANTRAJ.NS':'ANANTRAJ','ANANDRATHI.NS':'ANANDRATHI','PRUDENT.NS':'PRUDENT'})
stocks.columns
# Out:
# MultiIndex([( 'Close', 'ANANDRATHI'),
#             ( 'Close',   'ANANTRAJ'),
#             ( 'Close',     'INDIGO'),
#             ( 'Close',       'INFY'),
#             ( 'Close',   'KPITTECH'),
#             ( 'Close',    'PRUDENT'),
#             ( 'Close',   'RELIANCE'),
#             ( 'Close',       'SBIN'),
#             ( 'Close',  'SHILCTECH'),
#             ( 'Close', 'TATAMOTORS'),
#             ( 'Close',  'TATAPOWER'),
#             ( 'Close',        'TCS'),
#             ( 'Close',  'WAAREERTL'),
#             ( 'Close',     'ZENTEC'),
#             ( 'Close',       'NSEI'),
#             (  'High', 'ANANDRATHI'),
#             (  'High',   'ANANTRAJ'),
#             (  'High',     'INDIGO'),
#             (  'High',       'INFY'),
#             (  'High',   'KPITTECH'),
#             (  'High',    'PRUDENT'),
#             (  'High',   'RELIANCE'),
#             (  'High',       'SBIN'),
#             (  'High',  'SHILCTECH'),
#             (  'High', 'TATAMOTORS'),
# ...

# %%
#converts multindex to tuples
stocks.columns = stocks.columns.to_flat_index()
stocks.columns
# Out:
# Index([ ('Close', 'ANANDRATHI'),    ('Close', 'ANANTRAJ'),
#             ('Close', 'INDIGO'),        ('Close', 'INFY'),
#           ('Close', 'KPITTECH'),     ('Close', 'PRUDENT'),
#           ('Close', 'RELIANCE'),        ('Close', 'SBIN'),
#          ('Close', 'SHILCTECH'),  ('Close', 'TATAMOTORS'),
#          ('Close', 'TATAPOWER'),         ('Close', 'TCS'),
#          ('Close', 'WAAREERTL'),      ('Close', 'ZENTEC'),
#               ('Close', 'NSEI'),   ('High', 'ANANDRATHI'),
#            ('High', 'ANANTRAJ'),       ('High', 'INDIGO'),
#                ('High', 'INFY'),     ('High', 'KPITTECH'),
#             ('High', 'PRUDENT'),     ('High', 'RELIANCE'),
#                ('High', 'SBIN'),    ('High', 'SHILCTECH'),
#          ('High', 'TATAMOTORS'),    ('High', 'TATAPOWER'),
#                 ('High', 'TCS'),    ('High', 'WAAREERTL'),
#              ('High', 'ZENTEC'),         ('High', 'NSEI'),
#           ('Low', 'ANANDRATHI'),      ('Low', 'ANANTRAJ'),
# ...

# %%
stocks
# Out:
#             (Close, ANANDRATHI)  (Close, ANANTRAJ)  (Close, INDIGO)  \
# Date
# 2010-01-04                  NaN          49.145935              NaN
# 2010-01-05                  NaN          48.525452              NaN
# 2010-01-06                  NaN          52.248360              NaN
# 2010-01-07                  NaN          51.080395              NaN
# 2010-01-08                  NaN          52.522091              NaN
# ...                         ...                ...              ...
# 2025-07-25          2596.199951         573.450012           5803.0
# 2025-07-28          2643.600098         563.099976           5762.0
# 2025-07-29          2688.300049         578.400024           5756.0
# 2025-07-30          2671.399902         579.799988           5740.0
# 2025-07-31          2645.600098         564.599976           5910.5
#
#             (Close, INFY)  (Close, KPITTECH)  (Close, PRUDENT)  \
# Date
# 2010-01-04     233.268631                NaN               NaN
# ...

# %%
#converts tuples back to multiindex
stocks.columns = pd.MultiIndex.from_tuples(stocks.columns)

# %%
stocks.columns
# Out:
# MultiIndex([( 'Close', 'ANANDRATHI'),
#             ( 'Close',   'ANANTRAJ'),
#             ( 'Close',     'INDIGO'),
#             ( 'Close',       'INFY'),
#             ( 'Close',   'KPITTECH'),
#             ( 'Close',    'PRUDENT'),
#             ( 'Close',   'RELIANCE'),
#             ( 'Close',       'SBIN'),
#             ( 'Close',  'SHILCTECH'),
#             ( 'Close', 'TATAMOTORS'),
#             ( 'Close',  'TATAPOWER'),
#             ( 'Close',        'TCS'),
#             ( 'Close',  'WAAREERTL'),
#             ( 'Close',     'ZENTEC'),
#             ( 'Close',       'NSEI'),
#             (  'High', 'ANANDRATHI'),
#             (  'High',   'ANANTRAJ'),
#             (  'High',     'INDIGO'),
#             (  'High',       'INFY'),
#             (  'High',   'KPITTECH'),
#             (  'High',    'PRUDENT'),
#             (  'High',   'RELIANCE'),
#             (  'High',       'SBIN'),
#             (  'High',  'SHILCTECH'),
#             (  'High', 'TATAMOTORS'),
# ...

# %%
stocks.describe()
# Out:
#              Close                                                      \
#         ANANDRATHI     ANANTRAJ       INDIGO         INFY     KPITTECH
# count   899.000000  3846.000000  2401.000000  3846.000000  1554.000000
# mean   1097.256501    89.737788  1948.051275   729.700511   693.166596
# std     757.496702   162.248801  1225.137281   523.593244   565.520853
# min     264.045593     6.001701   682.268677   195.670746    34.009087
# 25%     342.206512    17.206278  1103.887329   304.322823   108.321617
# 50%     879.506165    24.043665  1606.199951   466.806061   561.674469
# 75%    1903.982910    59.678295  2105.050049  1280.104370  1252.521027
# max    2688.300049   934.425232  5976.500000  1971.954346  1851.276367
#
#                                                                         ...  \
#            PRUDENT     RELIANCE         SBIN    SHILCTECH   TATAMOTORS  ...
# count   792.000000  3846.000000  3846.000000  3116.000000  3846.000000  ...
# ...

# %%
close = stocks.loc[:,"Close"].copy()
close
# Out:
#              ANANDRATHI    ANANTRAJ  INDIGO         INFY     KPITTECH  \
# Date
# 2010-01-04          NaN   49.145935     NaN   233.268631          NaN
# 2010-01-05          NaN   48.525452     NaN   234.049896          NaN
# 2010-01-06          NaN   52.248360     NaN   230.634644          NaN
# 2010-01-07          NaN   51.080395     NaN   225.451630          NaN
# 2010-01-08          NaN   52.522091     NaN   220.018616          NaN
# ...                 ...         ...     ...          ...          ...
# 2025-07-25  2596.199951  573.450012  5803.0  1515.699951  1221.199951
# 2025-07-28  2643.600098  563.099976  5762.0  1516.000000  1192.800049
# 2025-07-29  2688.300049  578.400024  5756.0  1513.699951  1218.400024
# 2025-07-30  2671.399902  579.799988  5740.0  1519.000000  1268.500000
# 2025-07-31  2645.600098  564.599976  5910.5  1509.000000  1226.400024
#
#                 PRUDENT     RELIANCE        SBIN    SHILCTECH  TATAMOTORS  \
# Date
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
close.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
close.iloc[0,0]
# Out:
# np.float64(nan)

# %%
close.iloc[0]
# Out:
# ANANDRATHI            NaN
# ANANTRAJ        49.145935
# INDIGO                NaN
# INFY           233.268631
# KPITTECH              NaN
# PRUDENT               NaN
# RELIANCE       219.466110
# SBIN           188.699768
# SHILCTECH       28.150000
# TATAMOTORS     151.363586
# TATAPOWER      107.961967
# TCS            295.397400
# WAAREERTL             NaN
# ZENTEC                NaN
# NSEI          5232.200195
# Name: 2010-01-04 00:00:00, dtype: float64

# %%
close.div(close.iloc[0]).mul(100)
# Out:
#             ANANDRATHI     ANANTRAJ  INDIGO        INFY  KPITTECH  PRUDENT  \
# Date
# 2010-01-04         NaN   100.000000     NaN  100.000000       NaN      NaN
# 2010-01-05         NaN    98.737468     NaN  100.334921       NaN      NaN
# 2010-01-06         NaN   106.312678     NaN   98.870835       NaN      NaN
# 2010-01-07         NaN   103.936154     NaN   96.648927       NaN      NaN
# 2010-01-08         NaN   106.869654     NaN   94.319847       NaN      NaN
# ...                ...          ...     ...         ...       ...      ...
# 2025-07-25         NaN  1166.831014     NaN  649.765871       NaN      NaN
# 2025-07-28         NaN  1145.771212     NaN  649.894499       NaN      NaN
# 2025-07-29         NaN  1176.903082     NaN  648.908490       NaN      NaN
# 2025-07-30         NaN  1179.751666     NaN  651.180570       NaN      NaN
# 2025-07-31         NaN  1148.823346     NaN  646.893667       NaN      NaN
#
# ...

# %%
normclose = close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
#tcs = close.TCS.copy().to_frame()

# %%
#tcs

# %%
#tcs.shift(periods=1)

# %%
#tcs['lag1'] = tcs.shift(periods=1)

# %%
#tcs

# %%
#tcs['diff'] = tcs.TCS.sub(tcs.lag1)
#tcs['diff'] = tcs.TCS.diff(periods=1)
#tcs

# %%
#tcs['%change'] = tcs.TCS.div(tcs.lag1).sub(1).mul(100)
#tcs

# %%
#tcs['%change2'] = tcs.TCS.pct_change(periods=1).mul(100)
#tcs

# %%
#del tcs['diff']
#tcs

# %%
#resampling data to month end
#tcs.TCS.resample("ME").last()

# %%
#resampling data to last business day
#tcs.TCS.resample("BME").last().pct_change(periods=1).mul(100)

# %%
#del tcs['lag1']

# %%
#tcs

# %%
#ret = tcs.pct_change().dropna()

# %%
#ret

# %%
#ret.info()

# %%
#ret.plot(kind='hist',figsize=(12,8), bins = 100)
#plt.show()

# %%
#daily_mean_ret = ret.mean()
#daily_mean_ret

# %%
#var_daily_ret = ret.var()
#var_daily_ret

# %%
# std_daily = np.sqrt(var_daily_ret)
# std_daily

# %%
# annual_mean_ret = daily_mean_ret*252
# annual_mean_ret

# %%
# annual_var_ret = var_daily_ret*252
# annual_var_ret

# %%
# annual_std_ret= np.sqrt(annual_var_ret)
# annual_std_ret

# %%
normclose.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
ret = close.pct_change().dropna()
ret.head()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6440\1974114209.py:1: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   ret = close.pct_change().dropna()
#             ANANDRATHI  ANANTRAJ    INDIGO      INFY  KPITTECH   PRUDENT  \
# Date
# 2022-05-23   -0.035554 -0.000876  0.036654  0.009106 -0.018123 -0.071384
# 2022-05-24   -0.010815 -0.044737 -0.024461 -0.018660 -0.023072 -0.035848
# 2022-05-25   -0.000798 -0.060606 -0.022192 -0.021201 -0.062532 -0.017795
# 2022-05-26    0.000479 -0.026393  0.103637  0.009572  0.008324 -0.037449
# 2022-05-27    0.031292  0.051205  0.003111  0.026265  0.034325  0.076972
#
#             RELIANCE      SBIN  SHILCTECH  TATAMOTORS  TATAPOWER       TCS  \
# Date
# 2022-05-23 -0.006687 -0.003244  -0.046821    0.008254  -0.014791  0.008731
# ...

# %%
ret.describe().T
# Out:
#             count      mean       std       min       25%       50%       75%  \
# ANANDRATHI  791.0  0.002871  0.019374 -0.065375 -0.006410  0.001169  0.010544
# ANANTRAJ    791.0  0.003439  0.032377 -0.199970 -0.013165  0.002420  0.020203
# INDIGO      791.0  0.001761  0.017810 -0.080312 -0.008270  0.001362  0.011602
# INFY        791.0  0.000273  0.015285 -0.094227 -0.008155  0.000204  0.009095
# KPITTECH    791.0  0.001440  0.024578 -0.136857 -0.012964  0.000481  0.013910
# PRUDENT     791.0  0.002587  0.031556 -0.160489 -0.013900  0.001143  0.016076
# RELIANCE    791.0  0.000277  0.013432 -0.074851 -0.007924  0.000313  0.007503
# SBIN        791.0  0.000894  0.015166 -0.144040 -0.007338  0.000994  0.008303
# SHILCTECH   791.0  0.004666  0.036570 -0.099997 -0.019332 -0.000782  0.027176
# TATAMOTORS  791.0  0.000764  0.017879 -0.083027 -0.009329  0.000115  0.010780
# TATAPOWER   791.0  0.000885  0.018712 -0.124740 -0.007670  0.001523  0.009934
# ...

# %%
summary = ret.describe().T.loc[:,['mean','std']]
summary
# Out:
#                 mean       std
# ANANDRATHI  0.002871  0.019374
# ANANTRAJ    0.003439  0.032377
# INDIGO      0.001761  0.017810
# INFY        0.000273  0.015285
# KPITTECH    0.001440  0.024578
# PRUDENT     0.002587  0.031556
# RELIANCE    0.000277  0.013432
# SBIN        0.000894  0.015166
# SHILCTECH   0.004666  0.036570
# TATAMOTORS  0.000764  0.017879
# TATAPOWER   0.000885  0.018712
# TCS         0.000051  0.012906
# WAAREERTL   0.004120  0.035878
# ZENTEC      0.003229  0.032019
# NSEI        0.000564  0.008069

# %%
summary['mean'] = summary['mean']*252
summary['std'] = summary['std']*np.sqrt(252)
summary
# Out:
#                 mean       std
# ANANDRATHI  0.723380  0.307547
# ANANTRAJ    0.866675  0.513972
# INDIGO      0.443879  0.282733
# INFY        0.068773  0.242638
# KPITTECH    0.362828  0.390162
# PRUDENT     0.651816  0.500942
# RELIANCE    0.069868  0.213233
# SBIN        0.225225  0.240760
# SHILCTECH   1.175837  0.580525
# TATAMOTORS  0.192469  0.283812
# TATAPOWER   0.223139  0.297049
# TCS         0.012864  0.204881
# WAAREERTL   1.038229  0.569547
# ZENTEC      0.813720  0.508288
# NSEI        0.142201  0.128086

# %%
summary.plot.scatter(x='std', y= 'mean', figsize=(12,8),s = 50, fontsize=15)
for i in summary.index:
    plt.annotate(i,xy=(summary.loc[i,'std']+0.002, summary.loc[i,'mean']+0.002), size = 15)
plt.xlabel("Annual risk(std)",fontsize = 15)
plt.ylabel("Annual return",fontsize = 15)
plt.title("Risk/return",fontsize = 25)
plt.show()

# %% [markdown]
# ### Correlation and Covariance

# %%
ret
# Out:
#             ANANDRATHI  ANANTRAJ    INDIGO      INFY  KPITTECH   PRUDENT  \
# Date
# 2022-05-23   -0.035554 -0.000876  0.036654  0.009106 -0.018123 -0.071384
# 2022-05-24   -0.010815 -0.044737 -0.024461 -0.018660 -0.023072 -0.035848
# 2022-05-25   -0.000798 -0.060606 -0.022192 -0.021201 -0.062532 -0.017795
# 2022-05-26    0.000479 -0.026393  0.103637  0.009572  0.008324 -0.037449
# 2022-05-27    0.031292  0.051205  0.003111  0.026265  0.034325  0.076972
# ...                ...       ...       ...       ...       ...       ...
# 2025-07-25   -0.013302  0.019739 -0.007016 -0.023704 -0.020591 -0.027697
# 2025-07-28    0.018258 -0.018049 -0.007065  0.000198 -0.023256  0.008494
# 2025-07-29    0.016909  0.027171 -0.001041 -0.001517  0.021462  0.028485
# 2025-07-30   -0.006287  0.002420 -0.002780  0.003501  0.041119  0.019674
# 2025-07-31   -0.009658 -0.026216  0.029704 -0.006583 -0.033189 -0.046162
#
#             RELIANCE      SBIN  SHILCTECH  TATAMOTORS  TATAPOWER       TCS  \
# Date
# ...

# %%
ret.cov()
# Out:
#             ANANDRATHI  ANANTRAJ    INDIGO      INFY  KPITTECH   PRUDENT  \
# ANANDRATHI    0.000375  0.000103  0.000028  0.000018  0.000049  0.000078
# ANANTRAJ      0.000103  0.001048  0.000154  0.000098  0.000231  0.000293
# INDIGO        0.000028  0.000154  0.000317  0.000037  0.000087  0.000086
# INFY          0.000018  0.000098  0.000037  0.000234  0.000119  0.000058
# KPITTECH      0.000049  0.000231  0.000087  0.000119  0.000604  0.000162
# PRUDENT       0.000078  0.000293  0.000086  0.000058  0.000162  0.000996
# RELIANCE      0.000021  0.000131  0.000059  0.000054  0.000073  0.000085
# SBIN          0.000032  0.000186  0.000083  0.000046  0.000093  0.000107
# SHILCTECH     0.000090  0.000296  0.000072  0.000039  0.000165  0.000173
# TATAMOTORS    0.000029  0.000183  0.000090  0.000066  0.000114  0.000161
# TATAPOWER     0.000083  0.000289  0.000140  0.000051  0.000127  0.000191
# TCS           0.000014  0.000072  0.000030  0.000144  0.000091  0.000061
# ...

# %%
ret.corr()
# Out:
#             ANANDRATHI  ANANTRAJ    INDIGO      INFY  KPITTECH   PRUDENT  \
# ANANDRATHI    1.000000  0.164834  0.081351  0.061752  0.103814  0.126940
# ANANTRAJ      0.164834  1.000000  0.267761  0.198988  0.290447  0.287116
# INDIGO        0.081351  0.267761  1.000000  0.137536  0.199357  0.152762
# INFY          0.061752  0.198988  0.137536  1.000000  0.315670  0.119367
# KPITTECH      0.103814  0.290447  0.199357  0.315670  1.000000  0.208724
# PRUDENT       0.126940  0.287116  0.152762  0.119367  0.208724  1.000000
# RELIANCE      0.081048  0.301419  0.245530  0.265020  0.220379  0.199589
# SBIN          0.109272  0.378150  0.306850  0.198070  0.250332  0.224523
# SHILCTECH     0.127536  0.249652  0.110878  0.069170  0.183789  0.150220
# TATAMOTORS    0.083592  0.316795  0.283757  0.242464  0.260311  0.285766
# TATAPOWER     0.229820  0.477614  0.420320  0.180024  0.276199  0.323832
# TCS           0.056955  0.173088  0.132198  0.728793  0.286807  0.150288
# ...

# %%
plt.figure(figsize=(12,5))
sns.set(font_scale=.8)
sns.heatmap(ret.corr(),cmap= "Reds", annot = True, annot_kws={"size":10},vmax = 0.6)
plt.show()

# %% [markdown]
# ### simple returns and log returns

# %%
nifty = yf.download("^NSEI", start = "1995-01-01", end = "2025-08-01")
nifty
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6440\3487345370.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   nifty = yf.download("^NSEI", start = "1995-01-01", end = "2025-08-01")
# [*********************100%***********************]  1 of 1 completed
# Price              Close          High           Low          Open  Volume
# Ticker             ^NSEI         ^NSEI         ^NSEI         ^NSEI   ^NSEI
# Date
# 2007-09-17   4494.649902   4549.049805   4482.850098   4518.450195       0
# 2007-09-18   4546.200195   4551.799805   4481.549805   4494.100098       0
# 2007-09-19   4732.350098   4739.000000   4550.250000   4550.250000       0
# 2007-09-20   4747.549805   4760.850098   4721.149902   4734.850098       0
# 2007-09-21   4837.549805   4855.700195   4733.700195   4752.950195       0
# ...                  ...           ...           ...           ...     ...
# 2025-07-25  24837.000000  25010.349609  24806.349609  25010.349609  278100
# ...

# %%
nifty = nifty.Close
nifty
# Out:
# Ticker             ^NSEI
# Date
# 2007-09-17   4494.649902
# 2007-09-18   4546.200195
# 2007-09-19   4732.350098
# 2007-09-20   4747.549805
# 2007-09-21   4837.549805
# ...                  ...
# 2025-07-25  24837.000000
# 2025-07-28  24680.900391
# 2025-07-29  24821.099609
# 2025-07-30  24855.050781
# 2025-07-31  24768.349609
#
# [4384 rows x 1 columns]

# %%
nifty = nifty.rename(columns={"^NSEI":"close"})
nifty
# Out:
# Ticker             close
# Date
# 2007-09-17   4494.649902
# 2007-09-18   4546.200195
# 2007-09-19   4732.350098
# 2007-09-20   4747.549805
# 2007-09-21   4837.549805
# ...                  ...
# 2025-07-25  24837.000000
# 2025-07-28  24680.900391
# 2025-07-29  24821.099609
# 2025-07-30  24855.050781
# 2025-07-31  24768.349609
#
# [4384 rows x 1 columns]

# %%
nifty.plot(figsize = (12,8), fontsize = 15)
plt.legend(loc='upper left',fontsize = 15)
plt.show()

# %%
# example of rolling function

nifty_roll = nifty.rolling(window = 10)
nifty_roll = nifty_roll.mean()
nifty_roll
# Out:
# Ticker             close
# Date
# 2007-09-17           NaN
# 2007-09-18           NaN
# 2007-09-19           NaN
# 2007-09-20           NaN
# 2007-09-21           NaN
# ...                  ...
# 2025-07-25  25084.060156
# 2025-07-28  25043.920117
# 2025-07-29  25006.450000
# 2025-07-30  24970.750000
# 2025-07-31  24936.440039
#
# [4384 rows x 1 columns]

# %% [markdown]
# ### Creating and plotting simple moving averages

# %%
nifty
# Out:
# Ticker             close
# Date
# 2007-09-17   4494.649902
# 2007-09-18   4546.200195
# 2007-09-19   4732.350098
# 2007-09-20   4747.549805
# 2007-09-21   4837.549805
# ...                  ...
# 2025-07-25  24837.000000
# 2025-07-28  24680.900391
# 2025-07-29  24821.099609
# 2025-07-30  24855.050781
# 2025-07-31  24768.349609
#
# [4384 rows x 1 columns]

# %%
nifty["SMA50"] = nifty.rolling(window = 50, min_periods = 50).mean()

# %%
nifty
# Out:
# Ticker             close         SMA50
# Date
# 2007-09-17   4494.649902           NaN
# 2007-09-18   4546.200195           NaN
# 2007-09-19   4732.350098           NaN
# 2007-09-20   4747.549805           NaN
# 2007-09-21   4837.549805           NaN
# ...                  ...           ...
# 2025-07-25  24837.000000  25056.164023
# 2025-07-28  24680.900391  25050.873047
# 2025-07-29  24821.099609  25053.617031
# 2025-07-30  24855.050781  25054.449062
# 2025-07-31  24768.349609  25057.622070
#
# [4384 rows x 2 columns]

# %%
nifty["SMA200"] = nifty.close.rolling(window = 200, min_periods = 200).mean()
nifty
# Out:
# Ticker             close         SMA50        SMA200
# Date
# 2007-09-17   4494.649902           NaN           NaN
# 2007-09-18   4546.200195           NaN           NaN
# 2007-09-19   4732.350098           NaN           NaN
# 2007-09-20   4747.549805           NaN           NaN
# 2007-09-21   4837.549805           NaN           NaN
# ...                  ...           ...           ...
# 2025-07-25  24837.000000  25056.164023  24057.441270
# 2025-07-28  24680.900391  25050.873047  24055.780020
# 2025-07-29  24821.099609  25053.617031  24054.975771
# 2025-07-30  24855.050781  25054.449062  24054.258779
# 2025-07-31  24768.349609  25057.622070  24053.279277
#
# [4384 rows x 3 columns]

# %%
nifty.plot(figsize = (12,8), fontsize = 15)
plt.legend(loc='upper left',fontsize = 15)
plt.show()

# %%
stocks.Close
# Out:
#              ANANDRATHI    ANANTRAJ  INDIGO         INFY     KPITTECH  \
# Date
# 2010-01-04          NaN   49.145935     NaN   233.268631          NaN
# 2010-01-05          NaN   48.525452     NaN   234.049896          NaN
# 2010-01-06          NaN   52.248360     NaN   230.634644          NaN
# 2010-01-07          NaN   51.080395     NaN   225.451630          NaN
# 2010-01-08          NaN   52.522091     NaN   220.018616          NaN
# ...                 ...         ...     ...          ...          ...
# 2025-07-25  2596.199951  573.450012  5803.0  1515.699951  1221.199951
# 2025-07-28  2643.600098  563.099976  5762.0  1516.000000  1192.800049
# 2025-07-29  2688.300049  578.400024  5756.0  1513.699951  1218.400024
# 2025-07-30  2671.399902  579.799988  5740.0  1519.000000  1268.500000
# 2025-07-31  2645.600098  564.599976  5910.5  1509.000000  1226.400024
#
#                 PRUDENT     RELIANCE        SBIN    SHILCTECH  TATAMOTORS  \
# Date
# ...

# %%
anandrathi= stocks.Close.ANANDRATHI.to_frame().copy()
anandrathi
# Out:
#              ANANDRATHI
# Date
# 2010-01-04          NaN
# 2010-01-05          NaN
# 2010-01-06          NaN
# 2010-01-07          NaN
# 2010-01-08          NaN
# ...                 ...
# 2025-07-25  2596.199951
# 2025-07-28  2643.600098
# 2025-07-29  2688.300049
# 2025-07-30  2671.399902
# 2025-07-31  2645.600098
#
# [3848 rows x 1 columns]

# %% [markdown]
# ## Simple moving averages

# %%
anandrathi['SMA50'] = anandrathi.rolling(window=50, min_periods= 50).mean()

# %%
anandrathi['SMA200'] = anandrathi.ANANDRATHI.rolling(window=200, min_periods= 200).mean()

# %%
anandrathi
# Out:
#              ANANDRATHI        SMA50       SMA200
# Date
# 2010-01-04          NaN          NaN          NaN
# 2010-01-05          NaN          NaN          NaN
# 2010-01-06          NaN          NaN          NaN
# 2010-01-07          NaN          NaN          NaN
# 2010-01-08          NaN          NaN          NaN
# ...                 ...          ...          ...
# 2025-07-25  2596.199951  2129.655996  1965.576392
# 2025-07-28  2643.600098  2145.897998  1968.943308
# 2025-07-29  2688.300049  2163.345999  1972.128119
# 2025-07-30  2671.399902  2180.157996  1975.408242
# 2025-07-31  2645.600098  2196.187998  1978.590930
#
# [3848 rows x 3 columns]

# %%
anandrathi.plot(figsize=(12,8), fontsize = 10)
plt.legend(loc = 'upper left', fontsize = 10)
plt.show()

# %%
anantraj = stocks.Close.ANANTRAJ.to_frame().copy()
anantraj['SMA50'] = anantraj.rolling(window=50, min_periods= 50).mean()
anantraj['SMA200'] = anantraj.ANANTRAJ.rolling(window=200, min_periods= 200).mean()
anantraj.plot(figsize=(12,8), fontsize = 10)
plt.legend(loc = 'upper left', fontsize = 10)
plt.show()

# %% [markdown]
# ### Creating and plotting Exponential moving averages

# %%
nifty["EMA100"] = nifty.close.ewm(span = 100, min_periods=100).mean()

# %%
nifty.plot(figsize = (12,8), fontsize = 15)
plt.legend(loc='upper left',fontsize = 15)
plt.show()

# %%
nifty['day'] = nifty.index.day_name()

# %%
nifty['quarter'] = nifty.index.quarter

# %%
nifty
# Out:
# Ticker             close         SMA50        SMA200        EMA100        day  \
# Date
# 2007-09-17   4494.649902           NaN           NaN           NaN     Monday
# 2007-09-18   4546.200195           NaN           NaN           NaN    Tuesday
# 2007-09-19   4732.350098           NaN           NaN           NaN  Wednesday
# 2007-09-20   4747.549805           NaN           NaN           NaN   Thursday
# 2007-09-21   4837.549805           NaN           NaN           NaN     Friday
# ...                  ...           ...           ...           ...        ...
# 2025-07-25  24837.000000  25056.164023  24057.441270  24576.761093     Friday
# 2025-07-28  24680.900391  25050.873047  24055.780020  24578.823257     Monday
# 2025-07-29  24821.099609  25053.617031  24054.975771  24583.620809    Tuesday
# 2025-07-30  24855.050781  25054.449062  24054.258779  24588.995659  Wednesday
# 2025-07-31  24768.349609  25057.622070  24053.279277  24592.547223   Thursday
#
# Ticker      quarter
# ...

# %% [markdown]
# #### reindexing

# %%
nif = yf.download('^NSEI', start='2010-01-01', end = '2025-01-01')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6440\1482452963.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   nif = yf.download('^NSEI', start='2010-01-01', end = '2025-01-01')
# [*********************100%***********************]  1 of 1 completed

# %%
nif
# Out:
# Price              Close          High           Low          Open  Volume
# Ticker             ^NSEI         ^NSEI         ^NSEI         ^NSEI   ^NSEI
# Date
# 2010-01-04   5232.200195   5238.450195   5167.100098   5200.899902       0
# 2010-01-05   5277.899902   5288.350098   5242.399902   5277.149902       0
# 2010-01-06   5281.799805   5310.850098   5260.049805   5278.149902       0
# 2010-01-07   5263.100098   5302.549805   5244.750000   5281.799805       0
# 2010-01-08   5244.750000   5276.750000   5234.700195   5264.250000       0
# ...                  ...           ...           ...           ...     ...
# 2024-12-24  23727.650391  23867.650391  23685.150391  23769.099609  177700
# 2024-12-26  23750.199219  23854.500000  23653.599609  23775.800781  177700
# 2024-12-27  23813.400391  23938.849609  23800.599609  23801.400391  176800
# 2024-12-30  23644.900391  23915.349609  23599.300781  23796.900391  364900
# ...

# %%
all_days = pd.date_range(start = '2010-01-01', end= '2025-01-01',freq = 'D')

# %%
nif = nif.reindex(all_days)

# %%
nif
# Out:
# Price              Close          High           Low          Open    Volume
# Ticker             ^NSEI         ^NSEI         ^NSEI         ^NSEI     ^NSEI
# 2010-01-01           NaN           NaN           NaN           NaN       NaN
# 2010-01-02           NaN           NaN           NaN           NaN       NaN
# 2010-01-03           NaN           NaN           NaN           NaN       NaN
# 2010-01-04   5232.200195   5238.450195   5167.100098   5200.899902       0.0
# 2010-01-05   5277.899902   5288.350098   5242.399902   5277.149902       0.0
# ...                  ...           ...           ...           ...       ...
# 2024-12-28           NaN           NaN           NaN           NaN       NaN
# 2024-12-29           NaN           NaN           NaN           NaN       NaN
# 2024-12-30  23644.900391  23915.349609  23599.300781  23796.900391  364900.0
# 2024-12-31  23644.800781  23689.849609  23460.449219  23560.599609  193600.0
# ...

# %% [markdown]
# #### forward and backward fill

# %%
nif.fillna(method = 'ffill')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6440\1058460314.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   nif.fillna(method = 'ffill')
# Price              Close          High           Low          Open    Volume
# Ticker             ^NSEI         ^NSEI         ^NSEI         ^NSEI     ^NSEI
# 2010-01-01           NaN           NaN           NaN           NaN       NaN
# 2010-01-02           NaN           NaN           NaN           NaN       NaN
# 2010-01-03           NaN           NaN           NaN           NaN       NaN
# 2010-01-04   5232.200195   5238.450195   5167.100098   5200.899902       0.0
# 2010-01-05   5277.899902   5288.350098   5242.399902   5277.149902       0.0
# ...                  ...           ...           ...           ...       ...
# 2024-12-28  23813.400391  23938.849609  23800.599609  23801.400391  176800.0
# ...

# %%
nif.fillna(method='bfill')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6440\1581424814.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   nif.fillna(method='bfill')
# Price              Close          High           Low          Open    Volume
# Ticker             ^NSEI         ^NSEI         ^NSEI         ^NSEI     ^NSEI
# 2010-01-01   5232.200195   5238.450195   5167.100098   5200.899902       0.0
# 2010-01-02   5232.200195   5238.450195   5167.100098   5200.899902       0.0
# 2010-01-03   5232.200195   5238.450195   5167.100098   5200.899902       0.0
# 2010-01-04   5232.200195   5238.450195   5167.100098   5200.899902       0.0
# 2010-01-05   5277.899902   5288.350098   5242.399902   5277.149902       0.0
# ...                  ...           ...           ...           ...       ...
# 2024-12-28  23644.900391  23915.349609  23599.300781  23796.900391  364900.0
# ...

# %% [markdown]
# ### Cumulative returns, Drawdowns etc..

# %%
#tcs = yf.download("TCS.NS", start= '2002-01-01')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6440\235506779.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   tcs = yf.download("TCS.NS", start= '2002-01-01')
# [*********************100%***********************]  1 of 1 completed

# %%
#tcs
# Out:
# Price             Close         High          Low         Open   Volume
# Ticker           TCS.NS       TCS.NS       TCS.NS       TCS.NS   TCS.NS
# Date
# 2002-08-12    29.034960    29.254367    28.321883    28.321883   212976
# 2002-08-13    28.641850    29.537766    28.431585    29.071524   153576
# 2002-08-14    26.667192    28.705856    26.127813    28.705856   822776
# 2002-08-15    26.667192    26.667192    26.667192    26.667192        0
# 2002-08-16    26.603203    27.791662    26.146103    26.530068   811856
# ...                 ...          ...          ...          ...      ...
# 2025-07-28  3079.300049  3118.000000  3069.899902  3110.000000  3374473
# 2025-07-29  3056.000000  3074.000000  3041.199951  3060.000000  4785312
# 2025-07-30  3053.600098  3069.000000  3047.199951  3060.000000  2880121
# 2025-07-31  3036.800049  3059.800049  3015.000000  3041.699951  2968371
# 2025-08-01  3003.000000  3036.800049  3000.000000  3029.899902  2053847
#
# [5704 rows x 5 columns]

# %%
#tcs= tcs.Close

# %%
#tcs
# Out:
# Ticker           TCS.NS
# Date
# 2002-08-12    29.034960
# 2002-08-13    28.641850
# 2002-08-14    26.667192
# 2002-08-15    26.667192
# 2002-08-16    26.603203
# ...                 ...
# 2025-07-28  3079.300049
# 2025-07-29  3056.000000
# 2025-07-30  3053.600098
# 2025-07-31  3036.800049
# 2025-08-01  3003.000000
#
# [5704 rows x 1 columns]

# %%
tcs = tcs.rename(columns={"TCS.NS":"close"})

# %%
tcs
# Out:
# Ticker            close
# Date
# 2002-08-12    29.034960
# 2002-08-13    28.641850
# 2002-08-14    26.667192
# 2002-08-15    26.667192
# 2002-08-16    26.603203
# ...                 ...
# 2025-07-28  3079.300049
# 2025-07-29  3056.000000
# 2025-07-30  3053.600098
# 2025-07-31  3036.800049
# 2025-08-01  3003.000000
#
# [5704 rows x 1 columns]

# %%
#tcs['d_ret'] = np.log(tcs.div(tcs.shift(1)))

# %%
#tcs.dropna(inplace=True)

# %%
#tcs
# Out:
# Ticker            close     d_ret
# Date
# 2002-08-13    28.641850 -0.013632
# 2002-08-14    26.667192 -0.071435
# 2002-08-15    26.667192  0.000000
# 2002-08-16    26.603203 -0.002402
# 2002-08-19    25.944963 -0.025054
# ...                 ...       ...
# 2025-07-28  3079.300049 -0.018182
# 2025-07-29  3056.000000 -0.007595
# 2025-07-30  3053.600098 -0.000786
# 2025-07-31  3036.800049 -0.005517
# 2025-08-01  3003.000000 -0.011193
#
# [5703 rows x 2 columns]

# %%
#tcs.d_ret.sum()
# Out:
# np.float64(4.638866453934141)

# %%
# what if invested 1$ at the start

#np.exp(tcs.d_ret.sum())
# Out:
# np.float64(103.42704179375498)

# %%
#tcs['cumm_ret'] = tcs.d_ret.cumsum().apply(np.exp)

# %%
#tcs
# Out:
# Ticker            close     d_ret    cumm_ret
# Date
# 2002-08-13    28.641850 -0.013632    0.986461
# 2002-08-14    26.667192 -0.071435    0.918451
# 2002-08-15    26.667192  0.000000    0.918451
# 2002-08-16    26.603203 -0.002402    0.916247
# 2002-08-19    25.944963 -0.025054    0.893577
# ...                 ...       ...         ...
# 2025-07-28  3079.300049 -0.018182  106.054910
# 2025-07-29  3056.000000 -0.007595  105.252427
# 2025-07-30  3053.600098 -0.000786  105.169772
# 2025-07-31  3036.800049 -0.005517  104.591157
# 2025-08-01  3003.000000 -0.011193  103.427042
#
# [5703 rows x 3 columns]

# %%
#tcs.cumm_ret.plot(figsize=(12,8),title = "TCS buy and hold", fontsize = 8)
plt.show()

# %%
#tcs.d_ret.mean()*252
# Out:
# np.float64(0.2049788438350699)

# %%
#tcs.d_ret.std()*np.sqrt(252)
# Out:
# np.float64(0.4311938111152259)

# %% [markdown]
# #### How to calculate drawdowns

# %%
#tcs['cumm_max'] = tcs.cumm_ret.cummax()

# %%
#tcs
# Out:
# Ticker            close     d_ret    cumm_ret    cumm_max
# Date
# 2002-08-13    28.641850 -0.013632    0.986461    0.986461
# 2002-08-14    26.667192 -0.071435    0.918451    0.986461
# 2002-08-15    26.667192  0.000000    0.918451    0.986461
# 2002-08-16    26.603203 -0.002402    0.916247    0.986461
# 2002-08-19    25.944963 -0.025054    0.893577    0.986461
# ...                 ...       ...         ...         ...
# 2025-07-28  3079.300049 -0.018182  106.054910  154.184785
# 2025-07-29  3056.000000 -0.007595  105.252427  154.184785
# 2025-07-30  3053.600098 -0.000786  105.169772  154.184785
# 2025-07-31  3036.800049 -0.005517  104.591157  154.184785
# 2025-08-01  3003.000000 -0.011193  103.427042  154.184785
#
# [5703 rows x 4 columns]

# %%
# can be used to plot 52 week high or lows if optimized properly

#tcs[['cumm_ret','cumm_max']].plot(figsize=(12,8),title = "TCS buy and hold + cummmax", fontsize = 12)
#plt.show()

# %%
#tcs['drawdown'] =tcs['cumm_max'] - tcs['cumm_ret']

# %%
#tcs
# Out:
# Ticker            close     d_ret    cumm_ret    cumm_max   drawdown
# Date
# 2002-08-13    28.641850 -0.013632    0.986461    0.986461   0.000000
# 2002-08-14    26.667192 -0.071435    0.918451    0.986461   0.068010
# 2002-08-15    26.667192  0.000000    0.918451    0.986461   0.068010
# 2002-08-16    26.603203 -0.002402    0.916247    0.986461   0.070214
# 2002-08-19    25.944963 -0.025054    0.893577    0.986461   0.092884
# ...                 ...       ...         ...         ...        ...
# 2025-07-28  3079.300049 -0.018182  106.054910  154.184785  48.129875
# 2025-07-29  3056.000000 -0.007595  105.252427  154.184785  48.932357
# 2025-07-30  3053.600098 -0.000786  105.169772  154.184785  49.015013
# 2025-07-31  3036.800049 -0.005517  104.591157  154.184785  49.593627
# 2025-08-01  3003.000000 -0.011193  103.427042  154.184785  50.757743
#
# [5703 rows x 5 columns]

# %%
#tcs.drawdown.max()
# Out:
# np.float64(50.757742870654695)

# %%
#tcs.drawdown.idxmax()
# Out:
# Timestamp('2025-08-01 00:00:00')

# %%
#tcs.loc[(tcs.index <= '2025-08-01')]
# Out:
# Ticker            close     d_ret    cumm_ret    cumm_max   drawdown
# Date
# 2002-08-13    28.641850 -0.013632    0.986461    0.986461   0.000000
# 2002-08-14    26.667192 -0.071435    0.918451    0.986461   0.068010
# 2002-08-15    26.667192  0.000000    0.918451    0.986461   0.068010
# 2002-08-16    26.603203 -0.002402    0.916247    0.986461   0.070214
# 2002-08-19    25.944963 -0.025054    0.893577    0.986461   0.092884
# ...                 ...       ...         ...         ...        ...
# 2025-07-28  3079.300049 -0.018182  106.054910  154.184785  48.129875
# 2025-07-29  3056.000000 -0.007595  105.252427  154.184785  48.932357
# 2025-07-30  3053.600098 -0.000786  105.169772  154.184785  49.015013
# 2025-07-31  3036.800049 -0.005517  104.591157  154.184785  49.593627
# 2025-08-01  3003.000000 -0.011193  103.427042  154.184785  50.757743
#
# [5703 rows x 5 columns]

# %%
#tcs['drawdown%'] = (tcs['cumm_max'] - tcs['cumm_ret'])/tcs['cumm_max']

# %%
#tcs
# Out:
# Ticker            close     d_ret    cumm_ret    cumm_max   drawdown  \
# Date
# 2002-08-13    28.641850 -0.013632    0.986461    0.986461   0.000000
# 2002-08-14    26.667192 -0.071435    0.918451    0.986461   0.068010
# 2002-08-15    26.667192  0.000000    0.918451    0.986461   0.068010
# 2002-08-16    26.603203 -0.002402    0.916247    0.986461   0.070214
# 2002-08-19    25.944963 -0.025054    0.893577    0.986461   0.092884
# ...                 ...       ...         ...         ...        ...
# 2025-07-28  3079.300049 -0.018182  106.054910  154.184785  48.129875
# 2025-07-29  3056.000000 -0.007595  105.252427  154.184785  48.932357
# 2025-07-30  3053.600098 -0.000786  105.169772  154.184785  49.015013
# 2025-07-31  3036.800049 -0.005517  104.591157  154.184785  49.593627
# 2025-08-01  3003.000000 -0.011193  103.427042  154.184785  50.757743
#
# Ticker      drawdown%
# Date
# 2002-08-13   0.000000
# 2002-08-14   0.068943
# 2002-08-15   0.068943
# 2002-08-16   0.071177
# ...

# %%
#tcs['drawdown%'].max()
# Out:
# np.float64(0.6513466006499548)

# %%
#tcs['drawdown%'].idxmax()
# Out:
# Timestamp('2009-03-03 00:00:00')

# %%
#tcs.loc[(tcs.index <= '2009-03-03')]
# Out:
# Ticker          close     d_ret  cumm_ret  cumm_max  drawdown  drawdown%
# Date
# 2002-08-13  28.641850 -0.013632  0.986461  0.986461  0.000000   0.000000
# 2002-08-14  26.667192 -0.071435  0.918451  0.986461  0.068010   0.068943
# 2002-08-15  26.667192  0.000000  0.918451  0.986461  0.068010   0.068943
# 2002-08-16  26.603203 -0.002402  0.916247  0.986461  0.070214   0.071177
# 2002-08-19  25.944963 -0.025054  0.893577  0.986461  0.092884   0.094159
# ...               ...       ...       ...       ...       ...        ...
# 2009-02-25  93.181664  0.024958  3.209292  8.543299  5.334007   0.624350
# 2009-02-26  93.462723  0.003012  3.218972  8.543299  5.324327   0.623217
# 2009-02-27  93.637169  0.001865  3.224980  8.543299  5.318319   0.622514
# 2009-03-02  89.130730 -0.049323  3.069773  8.543299  5.473527   0.640681
# 2009-03-03  86.484993 -0.030133  2.978650  8.543299  5.564649   0.651347
#
# [1653 rows x 6 columns]

# %% [markdown]
# ## Creating and backtesting strategies

# %% [markdown]
# #### SMA Strategy

# %%
df = tcs.close.loc[(tcs.index >= '2000-01-01')].to_frame()

# %%
df
# Out:
#                   close
# Date
# 2002-08-13    28.641850
# 2002-08-14    26.667192
# 2002-08-15    26.667192
# 2002-08-16    26.603203
# 2002-08-19    25.944963
# ...                 ...
# 2025-07-28  3079.300049
# 2025-07-29  3056.000000
# 2025-07-30  3053.600098
# 2025-07-31  3036.800049
# 2025-08-01  3003.000000
#
# [5703 rows x 1 columns]

# %%
sma_s = 50
sma_l = 100

# %%
df['sma_s'] = df.close.rolling(sma_s).mean()
df['sma_l'] = df.close.rolling(sma_l).mean()

# %%
df.head()
# Out:
#                 close  sma_s  sma_l
# Date
# 2002-08-13  28.641850    NaN    NaN
# 2002-08-14  26.667192    NaN    NaN
# 2002-08-15  26.667192    NaN    NaN
# 2002-08-16  26.603203    NaN    NaN
# 2002-08-19  25.944963    NaN    NaN

# %%
df.tail()
# Out:
#                   close        sma_s        sma_l
# Date
# 2025-07-28  3079.300049  3366.261743  3399.360806
# 2025-07-29  3056.000000  3358.266699  3395.415146
# 2025-07-30  3053.600098  3349.680347  3391.060229
# 2025-07-31  3036.800049  3341.722124  3386.389138
# 2025-08-01  3003.000000  3332.345049  3380.841182

# %%
df.plot(figsize= (12,8), title = "TCS - SMA{} | SMA{}".format(sma_s,sma_l), fontsize = 8)
plt.show()

# %%
# to check specific years

df.loc['2016'].plot(figsize= (12,8), title = "TCS - SMA{} | SMA{}".format(sma_s,sma_l), fontsize = 8)
plt.show()

# %%
df.dropna(inplace=True)

# %%
pd.reset_option('display.max_rows')

# %%
df
# Out:
#                   close        sma_s        sma_l
# Date
# 2002-12-30    41.797180    32.162802    30.466870
# 2002-12-31    43.963821    32.486428    30.620089
# 2003-01-01    44.676899    32.826876    30.800186
# 2003-01-02    42.638237    33.136241    30.959897
# 2003-01-03    43.159332    33.467181    31.125458
# ...                 ...          ...          ...
# 2025-07-28  3079.300049  3366.261743  3399.360806
# 2025-07-29  3056.000000  3358.266699  3395.415146
# 2025-07-30  3053.600098  3349.680347  3391.060229
# 2025-07-31  3036.800049  3341.722124  3386.389138
# 2025-08-01  3003.000000  3332.345049  3380.841182
#
# [5604 rows x 3 columns]

# %%
# Buy and sell condition

df['position'] = np.where(df['sma_s'] > df['sma_l'],1,-1)
df
# Out:
#                   close        sma_s        sma_l  position  returnsB&H  \
# Date
# 2003-01-06    41.879471    33.780386    31.284803         1   -0.030103
# 2003-01-07    41.394928    34.079329    31.432081         1   -0.011637
# 2003-01-08    42.875927    34.398932    31.581095         1    0.035152
# 2003-01-09    43.296452    34.718536    31.722247         1    0.009760
# 2003-01-10    40.645294    34.990784    31.819335         1   -0.063188
# ...                 ...          ...          ...       ...         ...
# 2025-07-28  3079.300049  3366.261743  3399.360806        -1   -0.018182
# 2025-07-29  3056.000000  3358.266699  3395.415146        -1   -0.007595
# 2025-07-30  3053.600098  3349.680347  3391.060229        -1   -0.000786
# 2025-07-31  3036.800049  3341.722124  3386.389138        -1   -0.005517
# 2025-08-01  3003.000000  3332.345049  3380.841182        -1   -0.011193
#
#             strategy  position2  strategy2
# Date
# 2003-01-06 -0.030103          1  -0.030103
# ...

# %%
df.loc['2019',['sma_s','sma_l','position']].plot(figsize= (12,8), title = "TCS - SMA{} | SMA{}".format(sma_s,sma_l), fontsize = 8,secondary_y = 'position')
plt.show()

# %%
df['returnsB&H'] = np.log(df.close.div(df.close.shift(1)))
df['strategy'] = df['returnsB&H']*df.position.shift(1)
df
# Out:
#                   close        sma_s        sma_l  position  returnsB&H  \
# Date
# 2002-12-30    41.797180    32.162802    30.466870         1         NaN
# 2002-12-31    43.963821    32.486428    30.620089         1    0.050538
# 2003-01-01    44.676899    32.826876    30.800186         1    0.016090
# 2003-01-02    42.638237    33.136241    30.959897         1   -0.046705
# 2003-01-03    43.159332    33.467181    31.125458         1    0.012147
# ...                 ...          ...          ...       ...         ...
# 2025-07-28  3079.300049  3366.261743  3399.360806        -1   -0.018182
# 2025-07-29  3056.000000  3358.266699  3395.415146        -1   -0.007595
# 2025-07-30  3053.600098  3349.680347  3391.060229        -1   -0.000786
# 2025-07-31  3036.800049  3341.722124  3386.389138        -1   -0.005517
# 2025-08-01  3003.000000  3332.345049  3380.841182        -1   -0.011193
#
#             strategy
# Date
# 2002-12-30       NaN
# 2002-12-31  0.050538
# 2003-01-01  0.016090
# ...

# %%
df.dropna(inplace=True)

# %%
df[['returnsB&H','strategy']].sum()
# Out:
# returnsB&H    4.274538
# strategy     -0.333565
# dtype: float64

# %%
df[['returnsB&H','strategy']].sum().apply(np.exp) #what 1$ will be in each strat
# Out:
# returnsB&H    71.846952
# strategy       0.716365
# dtype: float64

# %%
df[['returnsB&H','strategy']].std()*np.sqrt(252) # annual std deviation
# Out:
# returnsB&H    0.430478
# strategy      0.430647
# dtype: float64

# %% [markdown]
# #### strategy adjusted for long bias

# %%
df['position2'] = np.where(df['sma_s'] > df['sma_l'],1,0)
df['strategy2'] = df['returnsB&H']*df.position2.shift(1)
df.dropna(inplace=True)
df
# Out:
#                   close        sma_s        sma_l  position  returnsB&H  \
# Date
# 2003-01-07    41.394928    34.079329    31.432081         1   -0.011637
# 2003-01-08    42.875927    34.398932    31.581095         1    0.035152
# 2003-01-09    43.296452    34.718536    31.722247         1    0.009760
# 2003-01-10    40.645294    34.990784    31.819335         1   -0.063188
# 2003-01-13    41.056683    35.267238    31.921634         1    0.010071
# ...                 ...          ...          ...       ...         ...
# 2025-07-28  3079.300049  3366.261743  3399.360806        -1   -0.018182
# 2025-07-29  3056.000000  3358.266699  3395.415146        -1   -0.007595
# 2025-07-30  3053.600098  3349.680347  3391.060229        -1   -0.000786
# 2025-07-31  3036.800049  3341.722124  3386.389138        -1   -0.005517
# 2025-08-01  3003.000000  3332.345049  3380.841182        -1   -0.011193
#
#             strategy  position2  strategy2
# Date
# 2003-01-07 -0.011637          1  -0.011637
# ...

# %%
df[['returnsB&H','strategy2']].sum()
# Out:
# returnsB&H    4.272571
# strategy2     1.968520
# dtype: float64

# %%
df[['returnsB&H','strategy2']].sum().apply(np.exp)
# Out:
# returnsB&H    71.705777
# strategy2      7.160070
# dtype: float64

# %%
df[['returnsB&H','strategy2']].std()*np.sqrt(252)
# Out:
# returnsB&H    0.430354
# strategy2     0.274487
# dtype: float64

# %% [markdown]
# ## Creating function

# %%
def test_strategy(stock, start, end,SMA):
    df = yf.download(stock, start = start, end=end)
    data = df.Close
    data = data.rename(columns= {stock : "Close"})
    data['returns'] = np.log(data.Close.div(data.Close.shift(1)))
    data['SMA_S'] = data.Close.rolling(int(SMA[0])).mean()
    data['SMA_L'] = data.Close.rolling(int(SMA[1])).mean()
    data.dropna(inplace=True)

    data['Position'] = np.where(data['SMA_S'] > data['SMA_L'],1,-1)
    data['Strategy'] = data['returns']*data.Position.shift(1)
    data.dropna(inplace=True)
    ret = np.exp(data['Strategy'].sum())
    std = data['Strategy'].std()*np.sqrt(252)

    return ret,std

# %%
test_strategy('AAPL','2000-01-01','2025-08-01',(50,100))
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6440\2154433819.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(stock, start = start, end=end)
# [*********************100%***********************]  1 of 1 completed
# (np.float64(7.1633181870945455), np.float64(0.39295319014033))

# %% [markdown]
# ## Creating class

# %%
class SMABacktester():
    def __init__(self,symbol,SMA_S,SMA_L, start, end):
        self.symbol = symbol
        self.SMA_S = SMA_S
        self.SMA_L = SMA_L
        self.start = start
        self.end = end
        self.results = None
        self.get_data()

    def get_data(self):
        df = yf.download(self.symbol, start = self.start, end= self.end)
        data = df.Close
        data = data.rename(columns= {self.symbol : "Close"})
        data['returns'] = np.log(data.Close.div(data.Close.shift(1)))
        data['SMA_S'] = data.Close.rolling(self.SMA_S).mean()
        data['SMA_L'] = data.Close.rolling(self.SMA_L).mean()
        data.dropna(inplace=True)
        self.data2 = data

        return data
    
    def test_results(self):
        data = self.data2.copy().dropna()
        data['Position'] = np.where(data['SMA_S'] > data['SMA_L'],1,-1)
        data['Strategy'] = data['returns']*data.Position.shift(1)
        data.dropna(inplace=True)
        data['ret_B&H'] = data['returns'].cumsum().apply(np.exp)
        data['ret_strat'] = data['Strategy'].cumsum().apply(np.exp)
        perf = data['ret_strat'].iloc[-1]
        outperf = perf - data['ret_B&H'].iloc[-1]
        self.results = data
        ret = np.exp(data['Strategy'].sum())
        std = data['Strategy'].std()*np.sqrt(252)

        return round(perf,6) , round(outperf,6)
    
    def plot_results(self):
        if self.results is None:
            print("Run the test please")
        else:
            title ="{}| SMA_S = {} | SMA_L{}".format(self.symbol, self.SMA_S, self.SMA_L)
            self.results[['ret_B&H','ret_strat']].plot(title = title , figsize = (12,8))

# %%
tester = SMABacktester("SPY", 50 ,100, '2000-01-01', '2020-01-01')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6440\4198573308.py:12: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.symbol, start = self.start, end= self.end)
# [*********************100%***********************]  1 of 1 completed

# %%
tester.test_results()
# Out:
# (np.float64(3.760717), np.float64(0.43083))

# %%
tester.plot_results()
